# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

import requests

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descr = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_descr})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kandry
# Processing Record 2 of Set 1 | kormilovka
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | przasnysz
# Processing Record 6 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | esperance
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | henties bay
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | kahului
# Processing Record 16 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 1 | seoul
# Processing Record 18 of Set 1 | emerald
# Processing Record 19 of Set 1 | kutum
# Processing Record 20 of Set 1 | rosarito
# Processing Record 21 of Set 1 | andarab
# City not found. Skipping...
# Processing Record 22 of Set 1 | sorong
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | beringovskiy
# Processing Record 25 of Set 1 | middelburg
# Processing Record 26 of Set 1 | kruisfontein
# Processing Record 27 of Set 1 | zhoucheng
# Processing Record 28 of Set 1 | yar-sale
# Processing Record 29 of Set 1 | pedernales
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | rio gallegos
# Processing Record 34 of Set 1 | tayzhina
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | sao joao da barra
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | sao filipe
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | sitka
# Processing Record 41 of Set 1 | te anau
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | walvis bay
# Processing Record 44 of Set 1 | mount isa
# Processing Record 45 of Set 1 | kodiak
# Processing Record 46 of Set 1 | caska
# Processing Record 47 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 1 | linjiang
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | saint-pierre
# Processing Record 1 of Set 2 | juybar
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | coquimbo
# Processing Record 4 of Set 2 | lazaro cardenas
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | truth or consequences
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | ust-nera
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | mandan
# Processing Record 11 of Set 2 | qitaihe
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | plouzane
# Processing Record 14 of Set 2 | rosetta
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | rabo de peixe
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | talnakh
# Processing Record 19 of Set 2 | rochegda
# Processing Record 20 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | samarai
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | ixtapa
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | romitan
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | vanimo
# Processing Record 31 of Set 2 | touros
# Processing Record 32 of Set 2 | bandarbeyla
# Processing Record 33 of Set 2 | nampula
# Processing Record 34 of Set 2 | dunedin
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | vryburg
# Processing Record 38 of Set 2 | ouango
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | los llanos de aridane
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | norman wells
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | praia da vitoria
# Processing Record 45 of Set 2 | port-gentil
# Processing Record 46 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | sibolga
# Processing Record 49 of Set 2 | erenhot
# Processing Record 50 of Set 2 | goderich
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | owensboro
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | aksarka
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | turayf
# Processing Record 8 of Set 3 | labuhan
# Processing Record 9 of Set 3 | gollere
# City not found. Skipping...
# Processing Record 10 of Set 3 | sorland
# Processing Record 11 of Set 3 | padang
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | bay roberts
# Processing Record 15 of Set 3 | elmira
# Processing Record 16 of Set 3 | nikolskoye
# Processing Record 17 of Set 3 | bethel
# Processing Record 18 of Set 3 | marystown
# Processing Record 19 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 3 | rantoul
# Processing Record 21 of Set 3 | rovenki
# Processing Record 22 of Set 3 | port lincoln
# Processing Record 23 of Set 3 | atuona
# Processing Record 24 of Set 3 | puri
# Processing Record 25 of Set 3 | tecuala
# Processing Record 26 of Set 3 | lalmohan
# Processing Record 27 of Set 3 | olafsvik
# Processing Record 28 of Set 3 | faya
# Processing Record 29 of Set 3 | micheweni
# Processing Record 30 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 3 | chinsali
# Processing Record 32 of Set 3 | chara
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | les escoumins
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | vaini
# Processing Record 37 of Set 3 | ler
# Processing Record 38 of Set 3 | kavaratti
# Processing Record 39 of Set 3 | turukhansk
# Processing Record 40 of Set 3 | alice springs
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 3 | ilulissat
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | bilma
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | chuarrancho
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | road town
# Processing Record 50 of Set 3 | lorengau
# Processing Record 1 of Set 4 | antofagasta
# Processing Record 2 of Set 4 | chitral
# Processing Record 3 of Set 4 | podgornoye
# Processing Record 4 of Set 4 | golden
# Processing Record 5 of Set 4 | lemesos
# City not found. Skipping...
# Processing Record 6 of Set 4 | elverum
# Processing Record 7 of Set 4 | dalvik
# Processing Record 8 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | kjollefjord
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | lavrentiya
# Processing Record 13 of Set 4 | nanakuli
# Processing Record 14 of Set 4 | tahta
# Processing Record 15 of Set 4 | nizhnevartovsk
# Processing Record 16 of Set 4 | tarko-sale
# Processing Record 17 of Set 4 | ancud
# Processing Record 18 of Set 4 | lompoc
# Processing Record 19 of Set 4 | sept-iles
# Processing Record 20 of Set 4 | anzio
# Processing Record 21 of Set 4 | la ronge
# Processing Record 22 of Set 4 | tuatapere
# Processing Record 23 of Set 4 | okaihau
# Processing Record 24 of Set 4 | kahramanmaras
# Processing Record 25 of Set 4 | lasa
# Processing Record 26 of Set 4 | moranbah
# Processing Record 27 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 4 | roszke
# Processing Record 29 of Set 4 | geraldton
# Processing Record 30 of Set 4 | pisco
# Processing Record 31 of Set 4 | martinsville
# Processing Record 32 of Set 4 | mahibadhoo
# Processing Record 33 of Set 4 | killybegs
# Processing Record 34 of Set 4 | aguimes
# Processing Record 35 of Set 4 | coihaique
# Processing Record 36 of Set 4 | buchanan
# Processing Record 37 of Set 4 | zholymbet
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | havoysund
# Processing Record 40 of Set 4 | dikson
# Processing Record 41 of Set 4 | olden
# Processing Record 42 of Set 4 | lebu
# Processing Record 43 of Set 4 | dzaoudzi
# Processing Record 44 of Set 4 | atarasquillo
# City not found. Skipping...
# Processing Record 45 of Set 4 | naron
# Processing Record 46 of Set 4 | axim
# Processing Record 47 of Set 4 | giresun
# Processing Record 48 of Set 4 | hamilton
# Processing Record 49 of Set 4 | statesboro
# Processing Record 50 of Set 4 | bubaque
# Processing Record 1 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 5 | iqaluit
# Processing Record 3 of Set 5 | mount darwin
# Processing Record 4 of Set 5 | derzhavinsk
# Processing Record 5 of Set 5 | roebourne
# Processing Record 6 of Set 5 | capao da canoa
# Processing Record 7 of Set 5 | zhangjiakou
# Processing Record 8 of Set 5 | denpasar
# Processing Record 9 of Set 5 | pangnirtung
# Processing Record 10 of Set 5 | victor harbor
# Processing Record 11 of Set 5 | komsomolskiy
# Processing Record 12 of Set 5 | sao domingos
# Processing Record 13 of Set 5 | pevek
# Processing Record 14 of Set 5 | new norfolk
# Processing Record 15 of Set 5 | dukat
# Processing Record 16 of Set 5 | rio de janeiro
# Processing Record 17 of Set 5 | tessalit
# Processing Record 18 of Set 5 | gaurnadi
# Processing Record 19 of Set 5 | hasaki
# Processing Record 20 of Set 5 | sechura
# Processing Record 21 of Set 5 | siuna
# Processing Record 22 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 5 | anahuac
# Processing Record 24 of Set 5 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 25 of Set 5 | yagodnoye
# Processing Record 26 of Set 5 | tautira
# Processing Record 27 of Set 5 | cooma
# Processing Record 28 of Set 5 | san cristobal
# Processing Record 29 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 5 | stornoway
# Processing Record 31 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 32 of Set 5 | grindavik
# Processing Record 33 of Set 5 | luganville
# Processing Record 34 of Set 5 | carutapera
# Processing Record 35 of Set 5 | oriximina
# Processing Record 36 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 5 | liwale
# Processing Record 38 of Set 5 | cherskiy
# Processing Record 39 of Set 5 | nichinan
# Processing Record 40 of Set 5 | ostrovnoy
# Processing Record 41 of Set 5 | raga
# Processing Record 42 of Set 5 | baykalovo
# Processing Record 43 of Set 5 | kavieng
# Processing Record 44 of Set 5 | turan
# Processing Record 45 of Set 5 | angoram
# Processing Record 46 of Set 5 | rosario
# Processing Record 47 of Set 5 | rocha
# Processing Record 48 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 5 | seydisehir
# Processing Record 50 of Set 5 | namatanai
# Processing Record 1 of Set 6 | ye
# City not found. Skipping...
# Processing Record 2 of Set 6 | cabedelo
# Processing Record 3 of Set 6 | sabang
# Processing Record 4 of Set 6 | khatanga
# Processing Record 5 of Set 6 | hojai
# Processing Record 6 of Set 6 | nemuro
# Processing Record 7 of Set 6 | coahuayana
# Processing Record 8 of Set 6 | marrakesh
# Processing Record 9 of Set 6 | sinnamary
# Processing Record 10 of Set 6 | puro
# Processing Record 11 of Set 6 | victoria
# Processing Record 12 of Set 6 | laguna
# Processing Record 13 of Set 6 | zyryanka
# Processing Record 14 of Set 6 | anadyr
# Processing Record 15 of Set 6 | svetlogorsk
# Processing Record 16 of Set 6 | matay
# Processing Record 17 of Set 6 | brae
# Processing Record 18 of Set 6 | hofn
# Processing Record 19 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 6 | elizabeth city
# Processing Record 21 of Set 6 | bertoua
# Processing Record 22 of Set 6 | gorele
# Processing Record 23 of Set 6 | riyadh
# Processing Record 24 of Set 6 | usinsk
# Processing Record 25 of Set 6 | kolomak
# Processing Record 26 of Set 6 | kimbe
# Processing Record 27 of Set 6 | ketchikan
# Processing Record 28 of Set 6 | athabasca
# Processing Record 29 of Set 6 | kununurra
# Processing Record 30 of Set 6 | jyvaskyla
# Processing Record 31 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 6 | ilo
# Processing Record 33 of Set 6 | ashcroft
# Processing Record 34 of Set 6 | yamada
# Processing Record 35 of Set 6 | buraydah
# Processing Record 36 of Set 6 | mahon
# Processing Record 37 of Set 6 | torrijos
# Processing Record 38 of Set 6 | gotsu
# Processing Record 39 of Set 6 | eufaula
# Processing Record 40 of Set 6 | korla
# Processing Record 41 of Set 6 | cap malheureux
# Processing Record 42 of Set 6 | tramore
# Processing Record 43 of Set 6 | tecoanapa
# Processing Record 44 of Set 6 | kenai
# Processing Record 45 of Set 6 | constitucion
# Processing Record 46 of Set 6 | trincomalee
# Processing Record 47 of Set 6 | ixmiquilpan
# Processing Record 48 of Set 6 | kailua
# Processing Record 49 of Set 6 | adrar
# Processing Record 50 of Set 6 | mayumba
# Processing Record 1 of Set 7 | tanete
# Processing Record 2 of Set 7 | ifanadiana
# Processing Record 3 of Set 7 | soligalich
# Processing Record 4 of Set 7 | bud
# Processing Record 5 of Set 7 | meulaboh
# Processing Record 6 of Set 7 | asau
# Processing Record 7 of Set 7 | auki
# Processing Record 8 of Set 7 | jizan
# Processing Record 9 of Set 7 | awbari
# Processing Record 10 of Set 7 | verkhoyansk
# Processing Record 11 of Set 7 | coos bay
# Processing Record 12 of Set 7 | bangkalan
# Processing Record 13 of Set 7 | longyearbyen
# Processing Record 14 of Set 7 | spassk
# Processing Record 15 of Set 7 | sisimiut
# Processing Record 16 of Set 7 | kloulklubed
# Processing Record 17 of Set 7 | campoverde
# Processing Record 18 of Set 7 | finale ligure
# Processing Record 19 of Set 7 | acapulco
# Processing Record 20 of Set 7 | sao miguel do araguaia
# Processing Record 21 of Set 7 | surt
# Processing Record 22 of Set 7 | stepnyak
# Processing Record 23 of Set 7 | lagoa
# Processing Record 24 of Set 7 | phalodi
# Processing Record 25 of Set 7 | clyde river
# Processing Record 26 of Set 7 | seymchan
# Processing Record 27 of Set 7 | gat
# Processing Record 28 of Set 7 | diamantino
# Processing Record 29 of Set 7 | belaya gora
# Processing Record 30 of Set 7 | kaitangata
# Processing Record 31 of Set 7 | ajdabiya
# Processing Record 32 of Set 7 | banjar
# Processing Record 33 of Set 7 | havre-saint-pierre
# Processing Record 34 of Set 7 | bonavista
# Processing Record 35 of Set 7 | bathsheba
# Processing Record 36 of Set 7 | kankon
# Processing Record 37 of Set 7 | bonthe
# Processing Record 38 of Set 7 | fleetwood
# Processing Record 39 of Set 7 | ciudad guayana
# Processing Record 40 of Set 7 | djambala
# Processing Record 41 of Set 7 | albanel
# Processing Record 42 of Set 7 | fuengirola
# Processing Record 43 of Set 7 | onega
# Processing Record 44 of Set 7 | misratah
# Processing Record 45 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 7 | rawson
# Processing Record 47 of Set 7 | guerrero negro
# Processing Record 48 of Set 7 | fairbanks
# Processing Record 49 of Set 7 | dingle
# Processing Record 50 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 8 | ambilobe
# Processing Record 2 of Set 8 | kasongo-lunda
# Processing Record 3 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 8 | sur
# Processing Record 5 of Set 8 | alofi
# Processing Record 6 of Set 8 | palmer
# Processing Record 7 of Set 8 | rehoboth
# Processing Record 8 of Set 8 | srednekolymsk
# Processing Record 9 of Set 8 | celestun
# Processing Record 10 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 11 of Set 8 | mogadishu
# Processing Record 12 of Set 8 | boyolangu
# Processing Record 13 of Set 8 | oak ridge
# Processing Record 14 of Set 8 | ushtobe
# Processing Record 15 of Set 8 | luderitz
# Processing Record 16 of Set 8 | honningsvag
# Processing Record 17 of Set 8 | suzhou
# Processing Record 18 of Set 8 | manitouwadge
# Processing Record 19 of Set 8 | puerto narino
# Processing Record 20 of Set 8 | leningradskiy
# Processing Record 21 of Set 8 | kardymovo
# Processing Record 22 of Set 8 | antalaha
# Processing Record 23 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 8 | uige
# Processing Record 25 of Set 8 | santa vitoria do palmar
# Processing Record 26 of Set 8 | souillac
# Processing Record 27 of Set 8 | itoman
# Processing Record 28 of Set 8 | healesville
# Processing Record 29 of Set 8 | wilmington
# Processing Record 30 of Set 8 | morondava
# Processing Record 31 of Set 8 | ahipara
# Processing Record 32 of Set 8 | mikuni
# Processing Record 33 of Set 8 | saint-augustin
# Processing Record 34 of Set 8 | makakilo city
# Processing Record 35 of Set 8 | rumuruti
# Processing Record 36 of Set 8 | iracoubo
# Processing Record 37 of Set 8 | uzhur-4
# City not found. Skipping...
# Processing Record 38 of Set 8 | novoderevyankovskaya
# Processing Record 39 of Set 8 | hervey bay
# Processing Record 40 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 8 | chase
# Processing Record 42 of Set 8 | cedral
# Processing Record 43 of Set 8 | teknaf
# Processing Record 44 of Set 8 | monzon
# Processing Record 45 of Set 8 | san carlos de bariloche
# Processing Record 46 of Set 8 | ossora
# Processing Record 47 of Set 8 | kirakira
# Processing Record 48 of Set 8 | pedro juan caballero
# Processing Record 49 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 8 | valky
# Processing Record 1 of Set 9 | savannah bight
# Processing Record 2 of Set 9 | isla mujeres
# Processing Record 3 of Set 9 | nouadhibou
# Processing Record 4 of Set 9 | soure
# Processing Record 5 of Set 9 | bilibino
# Processing Record 6 of Set 9 | peruibe
# Processing Record 7 of Set 9 | takaka
# Processing Record 8 of Set 9 | fortuna
# Processing Record 9 of Set 9 | bayan
# Processing Record 10 of Set 9 | agadir
# Processing Record 11 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 12 of Set 9 | yilan
# Processing Record 13 of Set 9 | juneau
# Processing Record 14 of Set 9 | mareeba
# Processing Record 15 of Set 9 | klaksvik
# Processing Record 16 of Set 9 | salym
# Processing Record 17 of Set 9 | balabac
# Processing Record 18 of Set 9 | hambantota
# Processing Record 19 of Set 9 | malatya
# Processing Record 20 of Set 9 | pontianak
# Processing Record 21 of Set 9 | moissala
# Processing Record 22 of Set 9 | nicoya
# Processing Record 23 of Set 9 | ende
# Processing Record 24 of Set 9 | inhambane
# Processing Record 25 of Set 9 | san rafael
# Processing Record 26 of Set 9 | peniche
# Processing Record 27 of Set 9 | ardakan
# Processing Record 28 of Set 9 | abu zabad
# Processing Record 29 of Set 9 | zabaykalsk
# Processing Record 30 of Set 9 | matadi
# Processing Record 31 of Set 9 | kang
# Processing Record 32 of Set 9 | kamen-na-obi
# Processing Record 33 of Set 9 | beyneu
# Processing Record 34 of Set 9 | posyet
# Processing Record 35 of Set 9 | deputatskiy
# Processing Record 36 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 37 of Set 9 | vestmanna
# Processing Record 38 of Set 9 | phuket
# Processing Record 39 of Set 9 | hirara
# Processing Record 40 of Set 9 | kovur
# Processing Record 41 of Set 9 | kupang
# Processing Record 42 of Set 9 | namibe
# Processing Record 43 of Set 9 | dwarka
# Processing Record 44 of Set 9 | katsuura
# Processing Record 45 of Set 9 | genhe
# Processing Record 46 of Set 9 | cam ranh
# Processing Record 47 of Set 9 | dubbo
# Processing Record 48 of Set 9 | aklavik
# Processing Record 49 of Set 9 | dungarvan
# Processing Record 50 of Set 9 | islahiye
# Processing Record 1 of Set 10 | lander
# Processing Record 2 of Set 10 | pouembout
# Processing Record 3 of Set 10 | olavarria
# Processing Record 4 of Set 10 | krasnyy chikoy
# Processing Record 5 of Set 10 | alta floresta
# Processing Record 6 of Set 10 | camalu
# Processing Record 7 of Set 10 | xiaolingwei
# Processing Record 8 of Set 10 | braganca
# Processing Record 9 of Set 10 | moose factory
# Processing Record 10 of Set 10 | batagay-alyta
# Processing Record 11 of Set 10 | srisailam
# Processing Record 12 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 10 | we
# City not found. Skipping...
# Processing Record 14 of Set 10 | saldanha
# Processing Record 15 of Set 10 | batagay
# Processing Record 16 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 10 | nishihara
# Processing Record 18 of Set 10 | mittagong
# Processing Record 19 of Set 10 | monte cristi
# City not found. Skipping...
# Processing Record 20 of Set 10 | yulara
# Processing Record 21 of Set 10 | machico
# Processing Record 22 of Set 10 | nome
# Processing Record 23 of Set 10 | russell
# Processing Record 24 of Set 10 | tweed
# Processing Record 25 of Set 10 | bustamante
# Processing Record 26 of Set 10 | agadez
# Processing Record 27 of Set 10 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 10 | cabo san lucas
# Processing Record 29 of Set 10 | tapel
# Processing Record 30 of Set 10 | karratha
# Processing Record 31 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 10 | marsa matruh
# Processing Record 33 of Set 10 | sao joao da boa vista
# Processing Record 34 of Set 10 | mizan teferi
# Processing Record 35 of Set 10 | nhulunbuy
# Processing Record 36 of Set 10 | nakamura
# Processing Record 37 of Set 10 | afsin
# Processing Record 38 of Set 10 | qandala
# Processing Record 39 of Set 10 | kuching
# Processing Record 40 of Set 10 | gua musang
# Processing Record 41 of Set 10 | baza
# Processing Record 42 of Set 10 | lokomotivnyy
# Processing Record 43 of Set 10 | altamonte springs
# Processing Record 44 of Set 10 | bassila
# Processing Record 45 of Set 10 | ojinaga
# Processing Record 46 of Set 10 | wanning
# Processing Record 47 of Set 10 | trelew
# Processing Record 48 of Set 10 | taoudenni
# Processing Record 49 of Set 10 | ofaqim
# Processing Record 50 of Set 10 | canutama
# Processing Record 1 of Set 11 | mitsamiouli
# Processing Record 2 of Set 11 | namwala
# Processing Record 3 of Set 11 | kastornoye
# Processing Record 4 of Set 11 | tarut
# Processing Record 5 of Set 11 | pemagatsel
# Processing Record 6 of Set 11 | eldorado
# Processing Record 7 of Set 11 | kharitonovo
# Processing Record 8 of Set 11 | nizwa
# Processing Record 9 of Set 11 | taltal
# Processing Record 10 of Set 11 | vao
# Processing Record 11 of Set 11 | minab
# Processing Record 12 of Set 11 | erzin
# Processing Record 13 of Set 11 | haines junction
# Processing Record 14 of Set 11 | wanxian
# Processing Record 15 of Set 11 | natal
# Processing Record 16 of Set 11 | gizo
# Processing Record 17 of Set 11 | nanortalik
# Processing Record 18 of Set 11 | verkhnyaya inta
# Processing Record 19 of Set 11 | tual
# Processing Record 20 of Set 11 | hobbs
# Processing Record 21 of Set 11 | alto piquiri
# Processing Record 22 of Set 11 | hualmay
# Processing Record 23 of Set 11 | sioux lookout
# Processing Record 24 of Set 11 | louveira
# Processing Record 25 of Set 11 | umm lajj
# Processing Record 26 of Set 11 | yumen
# Processing Record 27 of Set 11 | aykhal
# Processing Record 28 of Set 11 | mahebourg
# Processing Record 29 of Set 11 | qui nhon
# Processing Record 30 of Set 11 | deep river
# Processing Record 31 of Set 11 | christchurch
# Processing Record 32 of Set 11 | praya
# Processing Record 33 of Set 11 | hobyo
# Processing Record 34 of Set 11 | lower hutt
# Processing Record 35 of Set 11 | jumla
# Processing Record 36 of Set 11 | woodward
# Processing Record 37 of Set 11 | pine bluff
# Processing Record 38 of Set 11 | stanceni
# Processing Record 39 of Set 11 | husavik
# Processing Record 40 of Set 11 | nouakchott
# Processing Record 41 of Set 11 | margate
# Processing Record 42 of Set 11 | north bend
# Processing Record 43 of Set 11 | zuwarah
# Processing Record 44 of Set 11 | silver city
# Processing Record 45 of Set 11 | san cosme y damian
# Processing Record 46 of Set 11 | salta
# Processing Record 47 of Set 11 | kathu
# Processing Record 48 of Set 11 | lapeer
# Processing Record 49 of Set 11 | bayir
# Processing Record 50 of Set 11 | clinton
# Processing Record 1 of Set 12 | yayva
# Processing Record 2 of Set 12 | tura
# Processing Record 3 of Set 12 | bocas del toro
# Processing Record 4 of Set 12 | narsaq
# Processing Record 5 of Set 12 | roald
# Processing Record 6 of Set 12 | atar
# Processing Record 7 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 12 | serafimovich
# Processing Record 9 of Set 12 | tucuman
# Processing Record 10 of Set 12 | maragogi
# Processing Record 11 of Set 12 | lao cai
# Processing Record 12 of Set 12 | taybad
# Processing Record 13 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 12 | tiksi
# Processing Record 15 of Set 12 | rongai
# Processing Record 16 of Set 12 | charlottesville
# Processing Record 17 of Set 12 | raudeberg
# Processing Record 18 of Set 12 | osoyoos
# Processing Record 19 of Set 12 | bontang
# Processing Record 20 of Set 12 | nioro
# Processing Record 21 of Set 12 | monrovia
# Processing Record 22 of Set 12 | kamyshlov
# Processing Record 23 of Set 12 | roma
# Processing Record 24 of Set 12 | hit
# Processing Record 25 of Set 12 | moron
# Processing Record 26 of Set 12 | rio grande
# Processing Record 27 of Set 12 | lulea
# Processing Record 28 of Set 12 | hovd
# Processing Record 29 of Set 12 | sawakin
# Processing Record 30 of Set 12 | kyzyl-suu
# Processing Record 31 of Set 12 | krasnoturansk
# Processing Record 32 of Set 12 | raton
# Processing Record 33 of Set 12 | isangel
# Processing Record 34 of Set 12 | baykit
# Processing Record 35 of Set 12 | washington
# Processing Record 36 of Set 12 | cockburn town
# Processing Record 37 of Set 12 | huazolotitlan
# City not found. Skipping...
# Processing Record 38 of Set 12 | vardo
# Processing Record 39 of Set 12 | waddan
# Processing Record 40 of Set 12 | cruzeiro do oeste
# Processing Record 41 of Set 12 | okhotsk
# Processing Record 42 of Set 12 | changde
# Processing Record 43 of Set 12 | sambava
# Processing Record 44 of Set 12 | kholtoson
# Processing Record 45 of Set 12 | comodoro rivadavia
# Processing Record 46 of Set 12 | port macquarie
# Processing Record 47 of Set 12 | aktau
# Processing Record 48 of Set 12 | rundu
# Processing Record 49 of Set 12 | simbahan
# Processing Record 50 of Set 12 | tallahassee
# Processing Record 1 of Set 13 | puerto del rosario
# Processing Record 2 of Set 13 | avera
# Processing Record 3 of Set 13 | porto novo
# Processing Record 4 of Set 13 | orlik
# Processing Record 5 of Set 13 | forestville
# Processing Record 6 of Set 13 | tambopata
# Processing Record 7 of Set 13 | barra dos coqueiros
# Processing Record 8 of Set 13 | kaiwaka
# Processing Record 9 of Set 13 | atbasar
# Processing Record 10 of Set 13 | ahuimanu
# Processing Record 11 of Set 13 | breves
# Processing Record 12 of Set 13 | qaqortoq
# Processing Record 13 of Set 13 | vostok
# Processing Record 14 of Set 13 | potosi
# Processing Record 15 of Set 13 | epinal
# Processing Record 16 of Set 13 | cervo
# Processing Record 17 of Set 13 | waipawa
# Processing Record 18 of Set 13 | douglas
# Processing Record 19 of Set 13 | cayenne
# Processing Record 20 of Set 13 | solnechnyy
# Processing Record 21 of Set 13 | tilichiki
# Processing Record 22 of Set 13 | omsukchan
# Processing Record 23 of Set 13 | lensk
# Processing Record 24 of Set 13 | camabatela
# Processing Record 25 of Set 13 | najran
# Processing Record 26 of Set 13 | addi ugri
# City not found. Skipping...
# Processing Record 27 of Set 13 | camacha
# Processing Record 28 of Set 13 | matara
# Processing Record 29 of Set 13 | pontivy
# Processing Record 30 of Set 13 | venice
# Processing Record 31 of Set 13 | san quintin
# Processing Record 32 of Set 13 | angoche
# Processing Record 33 of Set 13 | tomatlan
# Processing Record 34 of Set 13 | nhlangano
# Processing Record 35 of Set 13 | alcudia
# Processing Record 36 of Set 13 | mount gambier
# Processing Record 37 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 13 | tres picos
# Processing Record 39 of Set 13 | zeya
# Processing Record 40 of Set 13 | faanui
# Processing Record 41 of Set 13 | bolshoy uluy
# City not found. Skipping...
# Processing Record 42 of Set 13 | west wendover
# Processing Record 43 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 44 of Set 13 | haimen
# Processing Record 45 of Set 13 | briancon
# Processing Record 46 of Set 13 | non sung
# Processing Record 47 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 13 | dudinka
# Processing Record 49 of Set 13 | tarancon
# Processing Record 50 of Set 13 | port augusta
# Processing Record 1 of Set 14 | kungurtug
# Processing Record 2 of Set 14 | sola
# Processing Record 3 of Set 14 | okha
# Processing Record 4 of Set 14 | xining
# Processing Record 5 of Set 14 | polis
# Processing Record 6 of Set 14 | foso
# Processing Record 7 of Set 14 | salalah
# Processing Record 8 of Set 14 | harper
# Processing Record 9 of Set 14 | lagunas
# Processing Record 10 of Set 14 | miramar
# Processing Record 11 of Set 14 | livingston
# Processing Record 12 of Set 14 | tarauaca
# Processing Record 13 of Set 14 | afanasyevo
# City not found. Skipping...
# Processing Record 14 of Set 14 | boddam
# Processing Record 15 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 16 of Set 14 | dolakovo
# Processing Record 17 of Set 14 | chicama
# Processing Record 18 of Set 14 | tadine
# Processing Record 19 of Set 14 | port shepstone
# Processing Record 20 of Set 14 | lahat
# Processing Record 21 of Set 14 | neftcala
# Processing Record 22 of Set 14 | montemorelos
# Processing Record 23 of Set 14 | svetlyy
# Processing Record 24 of Set 14 | wajima
# Processing Record 25 of Set 14 | son la
# Processing Record 26 of Set 14 | vitoria do mearim
# Processing Record 27 of Set 14 | buenos aires
# Processing Record 28 of Set 14 | puerto madryn
# Processing Record 29 of Set 14 | zyryanovsk
# Processing Record 30 of Set 14 | maxixe
# Processing Record 31 of Set 14 | anderson
# Processing Record 32 of Set 14 | diego de almagro
# Processing Record 33 of Set 14 | idaho falls
# Processing Record 34 of Set 14 | awjilah
# Processing Record 35 of Set 14 | carmo do paranaiba
# Processing Record 36 of Set 14 | granadilla de abona
# Processing Record 37 of Set 14 | staryy nadym
# Processing Record 38 of Set 14 | aluksne
# Processing Record 39 of Set 14 | banda aceh
# Processing Record 40 of Set 14 | catamarca
# Processing Record 41 of Set 14 | sobolevo
# Processing Record 42 of Set 14 | khani
# Processing Record 43 of Set 14 | tongchuan
# Processing Record 44 of Set 14 | sonoma
# Processing Record 45 of Set 14 | araguacu
# Processing Record 46 of Set 14 | flinders
# Processing Record 47 of Set 14 | neryungri
# Processing Record 48 of Set 14 | dera din panah
# City not found. Skipping...
# Processing Record 49 of Set 14 | hibbing
# Processing Record 50 of Set 14 | la tuque
# Processing Record 1 of Set 15 | salinas
# Processing Record 2 of Set 15 | nara
# Processing Record 3 of Set 15 | maningrida
# Processing Record 4 of Set 15 | guiratinga
# Processing Record 5 of Set 15 | niamey
# Processing Record 6 of Set 15 | novobirilyussy
# Processing Record 7 of Set 15 | prince rupert
# Processing Record 8 of Set 15 | panaba
# Processing Record 9 of Set 15 | itapeva
# Processing Record 10 of Set 15 | chunoyar
# Processing Record 11 of Set 15 | pontes e lacerda
# Processing Record 12 of Set 15 | akdagmadeni
# Processing Record 13 of Set 15 | gazojak
# Processing Record 14 of Set 15 | zinder
# Processing Record 15 of Set 15 | arman
# Processing Record 16 of Set 15 | oskemen
# Processing Record 17 of Set 15 | berekum
# Processing Record 18 of Set 15 | aswan
# Processing Record 19 of Set 15 | hanzhong
# Processing Record 20 of Set 15 | thinadhoo
# Processing Record 21 of Set 15 | sistranda
# Processing Record 22 of Set 15 | andijon
# Processing Record 23 of Set 15 | dioknisi
# Processing Record 24 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 25 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 15 | port hedland
# Processing Record 27 of Set 15 | moba
# Processing Record 28 of Set 15 | hays
# Processing Record 29 of Set 15 | fougamou
# Processing Record 30 of Set 15 | payo
# Processing Record 31 of Set 15 | am timan
# Processing Record 32 of Set 15 | kushiro
# Processing Record 33 of Set 15 | konde
# Processing Record 34 of Set 15 | yaan
# Processing Record 35 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 15 | george town
# Processing Record 37 of Set 15 | natchitoches
# Processing Record 38 of Set 15 | southbridge
# Processing Record 39 of Set 15 | shache
# Processing Record 40 of Set 15 | waitara
# Processing Record 41 of Set 15 | igarka
# Processing Record 42 of Set 15 | orange cove
# Processing Record 43 of Set 15 | iquitos
# Processing Record 44 of Set 15 | maroantsetra
# Processing Record 45 of Set 15 | panguna
# Processing Record 46 of Set 15 | betafo
# Processing Record 47 of Set 15 | pacific grove
# Processing Record 48 of Set 15 | evensk
# Processing Record 49 of Set 15 | aquiraz
# Processing Record 50 of Set 15 | smidovich
# Processing Record 1 of Set 16 | zanzibar
# Processing Record 2 of Set 16 | svetlaya
# Processing Record 3 of Set 16 | midland
# Processing Record 4 of Set 16 | aripuana
# Processing Record 5 of Set 16 | kagalnik
# Processing Record 6 of Set 16 | nanning
# Processing Record 7 of Set 16 | taft
# Processing Record 8 of Set 16 | colac
# Processing Record 9 of Set 16 | mehamn
# Processing Record 10 of Set 16 | casablanca
# Processing Record 11 of Set 16 | tommot
# Processing Record 12 of Set 16 | vakhrushev
# Processing Record 13 of Set 16 | pangody
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check the length of the data frame
len(city_data)
# Out:
# 706

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Kandry  54.5667   54.1167     -3.77        89         100       15.86
# 1  Kormilovka  55.0026   74.1028     28.40        93          75       15.66
# 2     Qaanaaq  77.4840  -69.3632      9.77        86          99        6.98
# 3     Ushuaia -54.8000  -68.3000     53.60        71          40       19.57
# 4   Przasnysz  53.0191   20.8803     10.00        84           0        7.25
# 5  Bredasdorp -34.5322   20.0403     69.80        73          62        6.91
# 6     Rikitea -23.1203 -134.9692     78.44        69         100        9.95
# 7   Esperance -33.8667  121.9000     59.00        94          90       11.50
# 8    Thompson  55.7435  -97.8558    -25.60        62          75       14.97
# 9   Busselton -33.6500  115.3333     59.00        97         100        1.99
#
#   Country Current Description
# 0      RU     overcast clouds
# 1      RU          light snow
# 2      GL     overcast clouds
# 3      AR    scattered clouds
# 4      PL           clear sky
# 5      ZA       broken clouds
# 6      PF     overcast clouds
# 7      AU          light rain
# 8      CA                snow
# 9      AU          light rain

# %%
# Reordering the columns of the dataframe
new_order=['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df=city_data_df[new_order]

# %%
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kandry      RU  54.5667   54.1167     -3.77        89         100
# 1  Kormilovka      RU  55.0026   74.1028     28.40        93          75
# 2     Qaanaaq      GL  77.4840  -69.3632      9.77        86          99
# 3     Ushuaia      AR -54.8000  -68.3000     53.60        71          40
# 4   Przasnysz      PL  53.0191   20.8803     10.00        84           0
# 5  Bredasdorp      ZA -34.5322   20.0403     69.80        73          62
# 6     Rikitea      PF -23.1203 -134.9692     78.44        69         100
# 7   Esperance      AU -33.8667  121.9000     59.00        94          90
# 8    Thompson      CA  55.7435  -97.8558    -25.60        62          75
# 9   Busselton      AU -33.6500  115.3333     59.00        97         100
#
#    Wind Speed Current Description
# 0       15.86     overcast clouds
# 1       15.66          light snow
# 2        6.98     overcast clouds
# 3       19.57    scattered clouds
# 4        7.25           clear sky
# 5        6.91       broken clouds
# 6        9.95     overcast clouds
# 7       11.50          light rain
# 8       14.97                snow
# 9        1.99          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
